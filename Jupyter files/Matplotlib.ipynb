# %%
import matplotlib.pyplot as plt

# %%
h = [2,4,6,8,10]

# %%
p = [20,40,60,80,100]

# %%
plt.plot(h,p,'r*--',color='#552255',lw=2,marker='o',markersize=40,markerfacecolor='#ff0000')
plt.xlabel('hrs')
plt.ylabel('Percentage')
plt.title('Marks')
plt.show()  # When run on command line it needed.

# %%
plt.scatter(h,p)

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)

# %%
plt.scatter(tips['total_bill'],tips['tip'])

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
sns.boxplot(x='sex',y='total_bill',data=tips)

# %%
sns.boxplot(x='sex',y='total_bill',data=tips,hue='smoker')

# %%
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
import plotly  #  We need net for plotting graph

# %%
import cufflinks as cf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-62-3178e833bc72> in <module>()
# ----> 1 import cufflinks as cf
#
# ModuleNotFoundError: No module named 'cufflinks'

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,iplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-63-ab439406f52b> in <module>()
# ----> 1 from plotly.offline import download_plotlyjs,init_notebook_mode,iplot
#
# ModuleNotFoundError: No module named 'plotly'

# %%
init_notebook_mode(connected=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-f9b08c18bcc6> in <module>()
# ----> 1 init_notebook_mode(connected=True)
#
# NameError: name 'init_notebook_mode' is not defined

# %%
cf.go_offline()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-88c82032df53> in <module>()
# ----> 1 cf.go_offline()
#
# NameError: name 'cf' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(100,4),columns=['a','b','c','d'])

# %%
df.plot()

# %%
df.iplot()   # It will highlight the points
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-69813823c9f3> in <module>()
# ----> 1 df.iplot()
#
# ~\Anaconda31\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
df.iplot(kind='scatter',x='a',y='b',mode='marker')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-bf8189f6e36c> in <module>()
# ----> 1 df.iplot(kind='scatter',x='a',y='b',mode='marker')
#
# ~\Anaconda31\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
df.iplot(kind='surface',colorscale='rdylbl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-a6a4826ed031> in <module>()
# ----> 1 df.iplot(kind='surface',colorscale='rdylbl')
#
# ~\Anaconda31\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
df.iplot(kind='surface')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-f0533dde9d36> in <module>()
# ----> 1 df.iplot(kind='surface')
#
# ~\Anaconda31\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
df.iplot(kind='bubble',x='a',y='b',size='c')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-c4f8a270ee19> in <module>()
# ----> 1 df.iplot(kind='bubble',x='a',y='b',size='c')
#
# ~\Anaconda31\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'
