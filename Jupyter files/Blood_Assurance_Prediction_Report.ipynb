# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

secure_random = random.SystemRandom()

HospitalList = []
with open (r'C:\Users\Prateek\Desktop\Ansible\Project\Dataset\HospitalsList.txt','r') as b:
    for x in b.readlines():
        p=x.strip('\n')
        HospitalList.append(p)

foo = []
with open (r'C:\Users\Prateek\Desktop\Ansible\Project\Dataset\DOCNAME.csv','r') as b:
    for x in b.readlines():
        p=x.strip('\n')
        foo.append(p)
        

df = np.random.randint(0,100)

raw_data = {'Name_Of_Hospital': [secure_random.choice(HospitalList) for i in range(30)],
            'Doctor1': [secure_random.choice(foo) for i in range(30)],
            'Doctor2': [secure_random.choice(foo) for i in range(30)],
            'FR1': ['Not Available' for i in range(30)],
            'FR2': ['Not Available' for i in range(30)],
            'Mobile1': [9000000000+np.random.randint(900000000,999999999) for i in range(30)],
            'Mobile2': [9000000000+np.random.randint(900000000,999999999) for i in range(30)],
}
df = pd.DataFrame(raw_data, columns = ['Name_Of_Hospital','Doctor1','Doctor2','FR1','FR2','Mobile1','Mobile2'])
df.to_csv(r'C:\Users\Prateek\Desktop\Ansible\Project\HospitalTable.csv')
df
# Out:
#                       Name_Of_Hospital                  Doctor1  \
# 0                      Aastha Hospital               Urmi Ghosh
# 1         Indraprastha Apollo hospital         Santosh Varghese
# 2               Jaipur Golden Hospital     Reuben Thomas Kurien
# 3                    Rockland Hospital              Manjunath K
# 4               Venketeshwara Hospital         Munaf B. Nandyal
# 5        BLK Super Speciality Hospital          Shyamkumar N.K.
# 6              Nanavati Super Hospital      Tony Thomson Chandy
# 7                     Jupiter Hospital   Vivi Miriam Srivastava
# 8                Paras Global Hospital           Roy Thankachen
# 9               Fortis Hospital Mulund                   Rupa V
# 10                   Narayana Hospital      Thilak S Jepegnanam
# 11  Woodland Multi speciality Hospital            Lovely Thomas
# 12       King Edward Memorial Hospital                    Roopa
# 13                      Paras Hospital         Riddhi Das Gupta
# 14                  SL Raheja Hospital            Sanjeev Kumar
# 15                Patna Heart Hospital           Georgene Singh
# 16                     Bombay Hospital     Annie Philip Villoth
# 17  Kokilaben Dhirubai Ambani Hospital      John Samuel Banerji
# 18            Greenview Medical Center            Santosh Kumar
# 19                     Apollo Hospital           Sandeep Albert
# 20                 B.P Poddar Hospital         Anika Amritanand
# 21                    Belle Vue Clinic      Dheepak Selvaraj A.
# 22                  SL Raheja Hospital              Deepu David
# 23  Kokilaben Dhirubai Ambani Hospital     Viju Daniel Varghese
# 24              Fortis Hospital Mulund           Prabhakar A.T.
# 25                       City Hospital             Prince James
# 26        Delhi State Cancer Institute  Abhay Gahukamble Deodas
# 27                      Pulse hospital            M Vinod Kumar
# 28       Dr.Ram Manohar Lohia Hospital      Selvin Sundar Raj M
# 29       BLK Super Speciality Hospital                 Anand R.
#
#                          Doctor2            FR1            FR2     Mobile1  \
# 0                   Jacob George  Not Available  Not Available  9966970952
# 1        Santosh Joseph Benjamin  Not Available  Not Available  9928203549
# 2                   Anila Korula  Not Available  Not Available  9973924384
# 3   Angel Miraclin Jebakumari T.  Not Available  Not Available  9954844470
# 4              Thomas Samuel Ram  Not Available  Not Available  9919996352
# 5               Riddhi Das Gupta  Not Available  Not Available  9917706279
# 6                   Susan Thomas  Not Available  Not Available  9971964127
# 7                    Thangadurai  Not Available  Not Available  9998660589
# 8             Jujju Jacob Kurian  Not Available  Not Available  9935945557
# 9                  Venkatesan S.  Not Available  Not Available  9938726826
# 10                 Tulasi Geevar  Not Available  Not Available  9975581048
# 11             Alfred Job Daniel  Not Available  Not Available  9909387092
# 12          Leenu Lizbeth Joseph  Not Available  Not Available  9919578674
# 13                       Abhinav  Not Available  Not Available  9947668919
# 14                 Sahana Shetty  Not Available  Not Available  9988428399
# 15           Vedantam Rajshekhar  Not Available  Not Available  9987803206
# 16                    Bina Isaac  Not Available  Not Available  9920263887
# 17            Shini Susan Samuel  Not Available  Not Available  9962282749
# 18                Ajit Sebastian  Not Available  Not Available  9924667341
# 19                    Balamugesh  Not Available  Not Available  9916384661
# 20            Lekha Mary Abraham  Not Available  Not Available  9937902218
# 21                    Sanil John  Not Available  Not Available  9942939442
# 22                   Shibu Jacob  Not Available  Not Available  9972620218
# 23             Santhosh Kumar. E  Not Available  Not Available  9935679558
# 24                Sivaranjini R.  Not Available  Not Available  9903900283
# 25       Vishnu Chandra Kumar A.  Not Available  Not Available  9952466048
# 26             Priya Mary Mammen  Not Available  Not Available  9927161253
# 27                   David Chase  Not Available  Not Available  9952486902
# 28              Maya Mary Mathew  Not Available  Not Available  9903004442
# 29                Lalee Varghese  Not Available  Not Available  9925746583
#
#        Mobile2
# 0   9922644494
# 1   9976505538
# 2   9981111726
# 3   9986893134
# 4   9998045620
# 5   9935815635
# 6   9989118459
# 7   9937203721
# 8   9987736573
# 9   9984284280
# 10  9944111643
# 11  9936055357
# 12  9985675868
# 13  9976545867
# 14  9957137909
# 15  9993290305
# 16  9933302949
# 17  9935150251
# 18  9956204671
# 19  9931009372
# 20  9956571144
# 21  9952921711
# 22  9944063352
# 23  9915937852
# 24  9921932239
# 25  9946354281
# 26  9927666099
# 27  9950272030
# 28  9942718048
# 29  9919893116

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date, timedelta

df = pd.read_csv(r'C:\Users\Prateek\Desktop\Ansible\Project\HospitalTable.csv')
for HospitalName in df['Name_Of_Hospital']:
    
    time = []
    def perdelta(start, end, delta):
        curr = start
        while curr < end:
            yield curr, min(curr + delta, end)
            curr += delta
    for s, e in perdelta(date(2018, 6, 16), date(2018, 7, 15), timedelta(days=1)):
             time.append(s)
            
    df = np.random.randint(0,100)
    raw_data = {
                'Date':[i for i in range(1,11)],
                'O+': [np.random.randint(50,70) for i in range(10)],
                'O-': [np.random.randint(60,80) for i in range(10)],
                'A+': [np.random.randint(40,70) for i in range(10)],
                'A-': [np.random.randint(30,60) for i in range(10)],
                'B+': [np.random.randint(50,80) for i in range(10)],
                'B-': [np.random.randint(60,80) for i in range(10)],
                'AB+': [np.random.randint(50,80) for i in range(10)],
                'AB-': [np.random.randint(60,90) for i in range(10)],
                'HH': [np.random.randint(0,10) for i in range(10)],
    }
    df = pd.DataFrame(raw_data, columns = ['Date','O+', 'O-', 'A+', 'A-', 'B+','B-','AB+','AB-','HH'])
    df.to_csv(r'C:\Users\Prateek\Desktop\Ansible\Project\BloodGroupDataset\{}.csv'.format(HospitalName))
    print("Blood group dataset of {} is created.".format(HospitalName))
# Out:
# Blood group dataset of Aastha Hospital is created.
# Blood group dataset of Indraprastha Apollo hospital is created.
# Blood group dataset of Jaipur Golden Hospital is created.
# Blood group dataset of Rockland Hospital is created.
# Blood group dataset of Venketeshwara Hospital is created.
# Blood group dataset of BLK Super Speciality Hospital is created.
# Blood group dataset of Nanavati Super Hospital is created.
# Blood group dataset of Jupiter Hospital is created.
# Blood group dataset of Paras Global Hospital is created.
# Blood group dataset of Fortis Hospital Mulund is created.
# Blood group dataset of Narayana Hospital is created.
# Blood group dataset of Woodland Multi speciality Hospital is created.
# Blood group dataset of King Edward Memorial Hospital is created.
# Blood group dataset of Paras Hospital is created.
# Blood group dataset of SL Raheja Hospital is created.
# Blood group dataset of Patna Heart Hospital is created.
# Blood group dataset of Bombay Hospital is created.
# Blood group dataset of Kokilaben Dhirubai Ambani Hospital is created.
# Blood group dataset of Greenview Medical Center is created.
# Blood group dataset of Apollo Hospital is created.
# Blood group dataset of B.P Poddar Hospital is created.
# Blood group dataset of Belle Vue Clinic is created.
# Blood group dataset of SL Raheja Hospital is created.
# Blood group dataset of Kokilaben Dhirubai Ambani Hospital is created.
# Blood group dataset of Fortis Hospital Mulund is created.
# Blood group dataset of City Hospital is created.
# Blood group dataset of Delhi State Cancer Institute is created.
# Blood group dataset of Pulse hospital is created.
# Blood group dataset of Dr.Ram Manohar Lohia Hospital is created.
# Blood group dataset of BLK Super Speciality Hospital is created.

# %%
                            # Prediction Only for next 30 days   (1)

import numpy as np
import pandas as pd
import sklearn
import sklearn.cross_validation as skcross
import sklearn.linear_model as sk_lm


HospitalName = str(input("Enter the Hospital name whose prediction is required:-   "))
x_test = int(input("Enter the Prediction value date:-  "))

data = pd.read_csv(r'C:\Users\Prateek\Desktop\Ansible\Project\BloodGroupDataset\{}.csv'.format(HospitalName))

ls = ['O+','O-','A+','A-','B+','B-','AB+','AB-','HH']

print("Predicted Blood group units that must be available on {} date:- ".format(x_test))

for i in range(1,10):
    x=data.iloc[:,0:1]
    y=data.iloc[:,i]

#    print(x)
#    print(y)
    x_train,x_testOld,y_train,y_testOld=skcross.train_test_split(x,y,test_size=0,random_state=20)

    
    model=sk_lm.LinearRegression()
    model.fit(x_train,y_train)
    y_predict=model.predict(x_test)

    print("\t For {} blood group :- {} units Predicted ".format(ls[i-1],int(y_predict)))
# Out:
# Enter the Hospital name whose prediction is required:-   AMRI Hospital
# Enter the Prediction value date:-  23
# Predicted Blood group units that must be available on 23 date:-
# 	 For O+ blood group :- 24 units Predicted
# 	 For O- blood group :- 73 units Predicted
# 	 For A+ blood group :- 69 units Predicted
# 	 For A- blood group :- 49 units Predicted
# 	 For B+ blood group :- 36 units Predicted
# 	 For B- blood group :- 61 units Predicted
# 	 For AB+ blood group :- 75 units Predicted
# 	 For AB- blood group :- 52 units Predicted
# 	 For HH blood group :- 90 units Predicted

# %%
                                    # Prediction Only for next 30 days   (2)
import numpy as np
import pandas as pd
import sklearn
import sklearn.cross_validation as skcross
import sklearn.linear_model as sk_lm


HospitalName = str(input("Enter the Hospital name whose prediction is required:-   "))
#curr_date = 
x_test = int(input("Enter the Prediction value date:-  "))
print("Blood units that must be donated by public before {} date is:- ".format(x_test))

df = pd.read_csv('D:\{}.csv'.format(HospitalName))

ls = ['O+','O-','A+','A-','B+','B-','AB+','AB-','HH']

print("Predicted Blood group units that must be available on {} date:- ".format(x_test))

for i in range(1,10):
    x=df.iloc[:,0:1]
    y=df.iloc[:,i]

#    print(x)
#    print(y)
    x_train,x_testOld,y_train,y_testOld=skcross.train_test_split(x,y,test_size=0,random_state=20)

    
    model=sk_lm.LinearRegression()
    model.fit(x_train,y_train)
    y_predict=model.predict(x_test)

    print("\t For {} blood group :- {} units Predicted ".format(ls[i-1],int(y_predict)))
    
    x = df.loc[9,ls[i-1]]
    print("\t \t \t {} units available".format(x))

# %%
                                    # Prediction Only for next 30 days   (3)
import numpy as np
import pandas as pd
import sklearn
import sklearn.cross_validation as skcross
import sklearn.linear_model as sk_lm


HospitalName = str(input("Enter the Hospital name whose prediction is required:-   "))
#curr_date = 
x_test = int(input("Enter the Prediction value date:-  "))
#print("Blood units that must be donated by public before {} date is:- ".format(x_test))

arrR = []
arrD = []

df = pd.read_csv(r'C:\Users\Prateek\Desktop\Ansible\Project\BloodGroupDataset\{}.csv'.format(HospitalName))

ls = ['O+','O-','A+','A-','B+','B-','AB+','AB-','HH']

#print("Predicted Blood group units that must be available on {} date:- ".format(x_test))

for i in range(1,10):
    x=df.iloc[:,0:1]
    y=df.iloc[:,i]

#    print(x)
#    print(y)
    x_train,x_testOld,y_train,y_testOld=skcross.train_test_split(x,y,test_size=0,random_state=20)

    
    model=sk_lm.LinearRegression()
    model.fit(x_train,y_train)
    y_predict=model.predict(x_test)

    print("\t For {} blood group :-".format(ls[i-1]))
    print("\t \t \t {} units Predicted ".format(int(y_predict)))
    
    x = df.loc[9,ls[i-1]]
    print("\t \t \t {} units available".format(x))
    
    transaction = x - int(y_predict) 
    if transaction > int(y_predict):
        print("You have to take {} units blood from Nearby Hospital:- ".format(transaction-int(y_predict)))
        arrR.append([HospitalName,ls[i-1],transaction-int(y_predict)])
    elif transaction < int(y_predict):
        print("You have to give {} units blood from Nearby Hospital:- ".format(int(y_predict)-x))
        arrD.append([HospitalName,ls[i-1],int(y_predict)-x])
    else:
        print("Nothing to do.")
    print()
# Out:
# Enter the Hospital name whose prediction is required:-   AMRI Hospital
# Enter the Prediction value date:-  23
# 	 For O+ blood group :-
# 	 	 	 24 units Predicted
# 	 	 	 65 units available
# You have to take 17 units blood from Nearby Hospital:-
#
# 	 For O- blood group :-
# 	 	 	 73 units Predicted
# 	 	 	 67 units available
# You have to give 6 units blood from Nearby Hospital:-
#
# 	 For A+ blood group :-
# 	 	 	 69 units Predicted
# 	 	 	 57 units available
# You have to give 12 units blood from Nearby Hospital:-
#
# 	 For A- blood group :-
# 	 	 	 49 units Predicted
# 	 	 	 53 units available
# You have to give -4 units blood from Nearby Hospital:-
#
# 	 For B+ blood group :-
# 	 	 	 36 units Predicted
# 	 	 	 60 units available
# You have to give -24 units blood from Nearby Hospital:-
#
# 	 For B- blood group :-
# 	 	 	 61 units Predicted
# 	 	 	 76 units available
# You have to give -15 units blood from Nearby Hospital:-
#
# 	 For AB+ blood group :-
# 	 	 	 75 units Predicted
# 	 	 	 73 units available
# You have to give 2 units blood from Nearby Hospital:-
#
# 	 For AB- blood group :-
# 	 	 	 52 units Predicted
# 	 	 	 86 units available
# You have to give -34 units blood from Nearby Hospital:-
#
# 	 For HH blood group :-
# 	 	 	 90 units Predicted
# 	 	 	 9 units available
# You have to give 81 units blood from Nearby Hospital:-

# %%
                                    # Prediction Only for next 30 days   (4)
import numpy as np
import pandas as pd
import sklearn
import sklearn.cross_validation as skcross
import sklearn.linear_model as sk_lm

arrR = []
arrD = []

df = pd.read_csv(r'C:\Users\Prateek\Desktop\Ansible\Project\HospitalTable.csv')

x_test = int(input("Enter the Prediction value date:-  "))


for HospitalName in df['Name_Of_Hospital']:

    df = pd.read_csv(r'C:\Users\Prateek\Desktop\Ansible\Project\BloodGroupDataset\{}.csv'.format(HospitalName))

    ls = ['O+','O-','A+','A-','B+','B-','AB+','AB-','HH']

    for i in range(1,10):
        x=df.iloc[:,0:1]
        y=df.iloc[:,i]

        x_train,x_testOld,y_train,y_testOld=skcross.train_test_split(x,y,test_size=0,random_state=20)


        model=sk_lm.LinearRegression()
        model.fit(x_train,y_train)
        y_predict=model.predict(x_test)

     #   print("\t For {} blood group :-".format(ls[i-1]))
     #   print("\t \t \t {} units Predicted ".format(int(y_predict)))

        x = df.loc[9,ls[i-1]]
     #   print("\t \t \t {} units available".format(x))

        transaction = x - int(y_predict) 
        if transaction > int(y_predict):
          #  print("You have to take {} units blood from Nearby Hospital:- ".format(transaction-int(y_predict)))
            arrR.append([HospitalName,ls[i-1],transaction-int(y_predict)])
        elif transaction < int(y_predict):
           # print("You have to give {} units blood from Nearby Hospital:- ".format(int(y_predict)-x))
            arrD.append([HospitalName,ls[i-1],int(y_predict)-x])
        else:
            print("")
       # print()
    
ch = input("Whether you need the details of Hospitals(Y/N):- ")
if ch=='Y':
            ls = ['O+','O-','A+','A-','B+','B-','AB+','AB-','HH']
            hosNameDonate = []
            hosNameReceive = []
            hospitalNamearrD =""
            hospitalNamearrR =""
            for bg in ls:

                
                for index in range(len(arrD)):
                    if arrD[index][1] == bg:
                        hospitalNamearrD = arrD[index][0]
                        break
                hosNameDonate.append([bg,hospitalNamearrD])
                for index in range(len(arrR)):
                    if arrR[index][1]==bg:
                        hospitalNamearrR = arrR[index][0]
                        break
                hosNameReceive.append([bg,hospitalNamearrR])
            print("\n Hospital Details where blood is needed:- \n")
            for index in range(len(hosNameDonate)):
                print(hosNameDonate[index][0]," : ", hosNameDonate[index][1])
            print("\n Hospital Details where blood is extra available:- \n")
            for index in range(len(hosNameReceive)):
                print(hosNameReceive[index][0], " : " , hosNameReceive[index][1])
elif ch=='N':
            print("Thank you for coming")
else:
            print("Wrong choice")
